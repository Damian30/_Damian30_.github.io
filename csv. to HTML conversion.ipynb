# %%
import pandas as pd

# %%
cities =('cities.csv')
df = pd.read_csv(cities)
df.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0       ushuaia          20      AR  1518757200        87 -54.81
# 1        1       rikitea          76      PF  1518760916       100 -23.12
# 2        2        baykit          48      RU  1518760917        72  61.68
# 3        3        putina           0      PE  1518760917        75 -14.91
# 4        4  san patricio          32      PY  1518760918        64 -26.98
#
#       Lng  Max Temp  Wind Speed
# 0  -68.31     51.80       17.22
# 1 -134.97     78.89       12.59
# 2   96.39     -0.09        4.43
# 3  -69.87     22.19        2.98
# 4  -56.83     74.57        3.98

# %%
df.set_index('City_ID', inplace=True)
df.head()
# Out:
#                  City  Cloudiness Country        Date  Humidity    Lat  \
# City_ID
# 0             ushuaia          20      AR  1518757200        87 -54.81
# 1             rikitea          76      PF  1518760916       100 -23.12
# 2              baykit          48      RU  1518760917        72  61.68
# 3              putina           0      PE  1518760917        75 -14.91
# 4        san patricio          32      PY  1518760918        64 -26.98
#
#             Lng  Max Temp  Wind Speed
# City_ID
# 0        -68.31     51.80       17.22
# 1       -134.97     78.89       12.59
# 2         96.39     -0.09        4.43
# 3        -69.87     22.19        2.98
# 4        -56.83     74.57        3.98

# %% [markdown]
# ### Data Frame conversion to HTML

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Wind Speed</th>\n    </tr>\n    <tr>\n      <th>City_ID</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>ushuaia</td>\n      <td>20</td>\n      <td>AR</td>\n      <td>1518757200</td>\n      <td>87</td>\n      <td>-54.81</td>\n      <td>-68.31</td>\n      <td>51.80</td>\n      <td>17.22</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>rikitea</td>\n      <td>76</td>\n      <td>PF</td>\n      <td>1518760916</td>\n      <td>100</td>\n      <td>-23.12</td>\n      <td>-134.97</td>\n      <td>78.89</td>\n      <td
# ...

# %%
#stripping new lines.

html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>City</th>      <th>Cloudiness</th>      <th>Country</th>      <th>Date</th>      <th>Humidity</th>      <th>Lat</th>      <th>Lng</th>      <th>Max Temp</th>      <th>Wind Speed</th>    </tr>    <tr>      <th>City_ID</th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>ushuaia</td>      <td>20</td>      <td>AR</td>      <td>1518757200</td>      <td>87</td>      <td>-54.81</td>      <td>-68.31</td>      <td>51.80</td>      <td>17.22</td>    </tr>    <tr>      <th>1</th>      <td>rikitea</td>      <td>76</td>      <td>PF</td>      <td>1518760916</td>      <td>100</td>      <td>-23.12</td>      <td>-134.97</td>      <td>78.89</td>      <td>12.59</td>    </tr>    <tr>      <th>2</th>      <td>baykit</td>      <td>48</td>      <td>RU</td> 
# ...

# %%
# saving file to html

df.to_html('citiestable.html')
